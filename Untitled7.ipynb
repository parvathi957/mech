# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 38.0 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=95dce746b66d02ad9b0e6200582fb1671d82aa98ba47cd3d4922b76a72516572
#   Stored in directory: /root/.cache/pip/wheels/19/39/2f/2d3cadc408a8804103f1c34ddd4b9f6a93497b11fa96fe738e
# Successfully built fire
# ...

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn. metrics import  accuracy_score

# %%
from deepface import DeepFace
# Out:
# 24-10-19 07:23:29 - Directory /root/.deepface has been created
# 24-10-19 07:23:29 - Directory /root/.deepface/weights has been created

# %%
import cv2
import matplotlib.pyplot as plt
img2 = cv2.imread ("/content/angry.img.jpg")
plt.imshow(img2 [:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img2 , actions = ['emotion'])
# Out:
# 24-10-19 07:23:40 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 74.2MB/s]

# %%
print(result)
# Out:
# [{'emotion': {'angry': 66.84505939483643, 'disgust': 0.034982775105163455, 'fear': 6.0984767973423, 'happy': 6.771057314836071e-05, 'sad': 26.03045403957367, 'surprise': 3.3833334356359046e-06, 'neutral': 0.9909612126648426}, 'dominant_emotion': 'angry', 'region': {'x': 3181, 'y': 1270, 'w': 1351, 'h': 1351, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.94}]

# %%
import cv2
import matplotlib.pyplot as plt
img2 = cv2.imread ("/content/happy.img.jpg")
plt.imshow(img2 [:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img2 , actions = ['emotion'])
# Out:
# 24-10-02 06:21:42 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 84.7MB/s]

# %%
print(result)
# Out:
# [{'emotion': {'angry': 3.6479249596595764, 'disgust': 0.00025276308406319004, 'fear': 39.35668170452118, 'happy': 0.06686049746349454, 'sad': 50.524914264678955, 'surprise': 0.4553486593067646, 'neutral': 5.948013067245483}, 'dominant_emotion': 'sad', 'region': {'x': 567, 'y': 495, 'w': 840, 'h': 840, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.92}, {'emotion': {'angry': 3.9474286139011383, 'disgust': 3.557470051873679e-06, 'fear': 0.012542153126560152, 'happy': 95.82238793373108, 'sad': 0.005663514457410201, 'surprise': 1.0074505496504571e-05, 'neutral': 0.21196629386395216}, 'dominant_emotion': 'happy', 'region': {'x': 403, 'y': 2043, 'w': 376, 'h': 376, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.96}]

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
emotions={0:'angry',1:'disgust',2:'fear',3:'happy',4:'sad',5:'surprise',6:'neutral'}

# %%
import cv2
import matplotlib.pyplot as plt
img2 = cv2.imread ("/content/suprised.img.jpg")
plt.imshow(img2 [:,:,::-1])
plt.show()

# %%
emotions={0:'angry',1:'disgust',2:'fear',3:'happy',4:'sad',5:'surprise',6:'neutral'}

# %%
result = DeepFace.analyze(img2 , actions = ['emotion'])

# %%
print(result)
# Out:
# [{'emotion': {'angry': 3.6479249596595764, 'disgust': 0.00025276308406319004, 'fear': 39.35668170452118, 'happy': 0.06686049746349454, 'sad': 50.524914264678955, 'surprise': 0.4553486593067646, 'neutral': 5.948013067245483}, 'dominant_emotion': 'sad', 'region': {'x': 567, 'y': 495, 'w': 840, 'h': 840, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.92}, {'emotion': {'angry': 3.9474286139011383, 'disgust': 3.557470051873679e-06, 'fear': 0.012542153126560152, 'happy': 95.82238793373108, 'sad': 0.005663514457410201, 'surprise': 1.0074505496504571e-05, 'neutral': 0.21196629386395216}, 'dominant_emotion': 'happy', 'region': {'x': 403, 'y': 2043, 'w': 376, 'h': 376, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.96}]

# %%
import cv2
import matplotlib.pyplot as plt
img2 = cv2.imread ("/content/upset.img.jpg")
plt.imshow(img2 [:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img2 , actions = ['emotion'])

# %%
print(result)
# Out:
# [{'emotion': {'angry': 3.6479249596595764, 'disgust': 0.00025276308406319004, 'fear': 39.35668170452118, 'happy': 0.06686049746349454, 'sad': 50.524914264678955, 'surprise': 0.4553486593067646, 'neutral': 5.948013067245483}, 'dominant_emotion': 'sad', 'region': {'x': 567, 'y': 495, 'w': 840, 'h': 840, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.92}, {'emotion': {'angry': 3.9474286139011383, 'disgust': 3.557470051873679e-06, 'fear': 0.012542153126560152, 'happy': 95.82238793373108, 'sad': 0.005663514457410201, 'surprise': 1.0074505496504571e-05, 'neutral': 0.21196629386395216}, 'dominant_emotion': 'happy', 'region': {'x': 403, 'y': 2043, 'w': 376, 'h': 376, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.96}]

# %%
import cv2
import matplotlib.pyplot as plt
img2 = cv2.imread ("/content/fear.img.jpg")
plt.imshow(img2 [:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img2 , actions = ['emotion'])

# %%
print(result)
# Out:
# [{'emotion': {'angry': 3.6479249596595764, 'disgust': 0.00025276308406319004, 'fear': 39.35668170452118, 'happy': 0.06686049746349454, 'sad': 50.524914264678955, 'surprise': 0.4553486593067646, 'neutral': 5.948013067245483}, 'dominant_emotion': 'sad', 'region': {'x': 567, 'y': 495, 'w': 840, 'h': 840, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.92}, {'emotion': {'angry': 3.9474286139011383, 'disgust': 3.557470051873679e-06, 'fear': 0.012542153126560152, 'happy': 95.82238793373108, 'sad': 0.005663514457410201, 'surprise': 1.0074505496504571e-05, 'neutral': 0.21196629386395216}, 'dominant_emotion': 'happy', 'region': {'x': 403, 'y': 2043, 'w': 376, 'h': 376, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.96}]

# %%
import cv2
import matplotlib.pyplot as plt
img2 = cv2.imread ("/content/neutral.img.jpg")
plt.imshow(img2 [:,:,::-1])
plt.show()

# %%
result = DeepFace.analyze(img2 , actions = ['emotion'])

# %%
print(result)
# Out:
# [{'emotion': {'angry': 3.6479249596595764, 'disgust': 0.00025276308406319004, 'fear': 39.35668170452118, 'happy': 0.06686049746349454, 'sad': 50.524914264678955, 'surprise': 0.4553486593067646, 'neutral': 5.948013067245483}, 'dominant_emotion': 'sad', 'region': {'x': 567, 'y': 495, 'w': 840, 'h': 840, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.92}, {'emotion': {'angry': 3.9474286139011383, 'disgust': 3.557470051873679e-06, 'fear': 0.012542153126560152, 'happy': 95.82238793373108, 'sad': 0.005663514457410201, 'surprise': 1.0074505496504571e-05, 'neutral': 0.21196629386395216}, 'dominant_emotion': 'happy', 'region': {'x': 403, 'y': 2043, 'w': 376, 'h': 376, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.96}]

# %%
basemodel = tf.keras.models.Sequential([tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D(2,2),
                                        tf.keras.layers.BatchNormalization(),
                                        #
                                        tf.keras.layers.Conv2D(64,(3,3),activation='relu',input_shape=(48,48,1)),
                                        tf.keras.layers.MaxPool2D(2,2),
                                        tf.keras.layers.BatchNormalization(),
                                        #
                                        tf.keras.layers.Conv2D(128,(3,3),activation='relu' ,input_shape=(48,48,1)),
                                        tf .keras.layers.MaxPool2D(2,2),
                                        tf.keras.layers.BatchNormalization(),
                                        #
                                        tf.keras.layers.Dense(128,activation='relu'),
                                        tf.keras.layers.Dense(7,activation='softmax')
                                        ])

                                        #
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
basemodel.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 23, 23, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...
